# %% [markdown]
# # Recipes for ML Model

# %% [markdown]
# ## Import JSON Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import json

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Data Reading

# %%
main_dir = 'drive/My Drive/Final'
datajson_dir = 'full_format_recipes.json'

# %%
# Read data from json and print tail
json_df = pd.read_json(os.path.join(main_dir, datajson_dir))
json_df.tail()
# Out:
#                                               directions  ...  sodium
# 20125  [Beat whites in a bowl with an electric mixer ...  ...    64.0
# 20126  [Bring broth to simmer in saucepan.Remove from...  ...   583.0
# 20127  [Using a sharp knife, cut a shallow X in botto...  ...   652.0
# 20128  [Heat 2 tablespoons oil in heavy medium skille...  ...   517.0
# 20129  [Position rack in bottom third of oven and pre...  ...  3698.0
#
# [5 rows x 11 columns]

# %%
# Shape of dataframe
json_df.shape
# Out:
# (20130, 11)

# %%
# Delete unnecesary columns
json_df = json_df.drop(['date', 'rating', 'categories'], axis=1)
json_df.tail()
# Out:
#                                               directions  ...  sodium
# 20125  [Beat whites in a bowl with an electric mixer ...  ...    64.0
# 20126  [Bring broth to simmer in saucepan.Remove from...  ...   583.0
# 20127  [Using a sharp knife, cut a shallow X in botto...  ...   652.0
# 20128  [Heat 2 tablespoons oil in heavy medium skille...  ...   517.0
# 20129  [Position rack in bottom third of oven and pre...  ...  3698.0
#
# [5 rows x 8 columns]

# %%
# Find how many NaN are in the columns
json_df.isna().sum()
# Out:
# directions       19
# fat            4222
# calories       4154
# desc           6635
# protein        4201
# title            19
# ingredients      19
# sodium         4156
# dtype: int64

# %%
# Find if there are 0 values in calories
json_df['calories'].eq(0).sum()
# Out:
# 13

# %%
# We will drop all the columns which has calories as 0 or NaN
# Calories is our main focus on the dataset, this is why we will
# drop for this column

json_df = json_df[json_df['calories'] != 0]
json_df.shape
# Out:
# (20117, 8)

# %%
json_df = json_df[json_df['calories'].notna()]
json_df.shape
# Out:
# (15963, 8)

# %%
# Let's check how many columns still has NaN
json_df.isna().sum()
# Out:
# directions        0
# fat              63
# calories          0
# desc           5328
# protein          42
# title             0
# ingredients       0
# sodium            2
# dtype: int64

# %%
# Reset the indexes
json_df = json_df.reset_index(drop=True)

# Make all NaN values zero
json_df = json_df.fillna(0)
json_df.isna().sum()
# Out:
# directions     0
# fat            0
# calories       0
# desc           0
# protein        0
# title          0
# ingredients    0
# sodium         0
# dtype: int64

# %%
# Let's check how many columns still has 0 values
json_df.eq(0).sum()
# Out:
# directions        0
# fat            1285
# calories          0
# desc           5328
# protein         891
# title             0
# ingredients       0
# sodium           54
# dtype: int64

# %%
json_df.columns
# Out:
# Index(['directions', 'fat', 'calories', 'desc', 'protein', 'title',
#        'ingredients', 'sodium'],
#       dtype='object')

# %%
# For last drop all columns with 0 value
for col in json_df.columns:
    json_df = json_df[json_df[col] != 0]

# %%
json_df.eq(0).sum()
# Out:
# directions     0
# fat            0
# calories       0
# desc           0
# protein        0
# title          0
# ingredients    0
# sodium         0
# dtype: int64

# %%
json_df = json_df.reset_index(drop=True)
json_df.shape
# Out:
# (9757, 8)

# %%
json_df.dtypes
# Out:
# directions      object
# fat            float64
# calories       float64
# desc            object
# protein        float64
# title           object
# ingredients     object
# sodium         float64
# dtype: object

# %%
# Make dictionary based on the object types columns

# *****************************************
# Esto todavía no
#******************************************

from sklearn.preprocessing import LabelEncoder
result_cat = []

label_encoder = LabelEncoder()
for var in label_encoder.fit_transform(json_df['title']):
    result_cat.append(var)

titles_encoded = pd.DataFrame(result_cat, columns=['result'])
titles_encoded.tail()
# Out:
#        result
# 15958    8551
# 15959     392
# 15960   13314
# 15961   11696
# 15962     712

# %%
#json_df['title'] = result['result']
json_df.tail()
# Out:
#                                              directions  ...  sodium
# 9752  [In a large pot, place the chicken legs, bay l...  ...   351.0
# 9753  [1. Preheat the oven to 400°F. Spray a baking ...  ...  1323.0
# 9754  [Bring broth to simmer in saucepan.Remove from...  ...   583.0
# 9755  [Heat 2 tablespoons oil in heavy medium skille...  ...   517.0
# 9756  [Position rack in bottom third of oven and pre...  ...  3698.0
#
# [5 rows x 8 columns]

# %%
# Separate the data into Snacks and Meal based on 250 calories
snacks = json_df[json_df['calories'] <= 250]
meals = json_df[json_df['calories'] > 250]

# %%
snacks.shape
# Out:
# (2889, 8)

# %%
meals.shape
# Out:
# (6868, 8)

# %%
snacks.head()
# Out:
#                                            directions  ...  sodium
# 2   [Stir together soy sauce, sugar, sesame oil, w...  ...  1272.0
# 6   [Sprinkle steaks with salt and pepper. Heat oi...  ...   176.0
# 7   [Using the tip of a paring knife, score an X i...  ...  1394.0
# 9   [Butter and sugar six 2/3-to 3/4-cup ramekins....  ...   160.0
# 13  [Gently combine the eggs, cucumbers, shallots,...  ...   250.0
#
# [5 rows x 8 columns]

# %%
snacks = snacks.sort_values('calories')
meals = meals.sort_values('calories')

train_snacks = snacks[['fat', 'calories', 'protein', 'sodium']]
snacks_desc = snacks[['directions', 'desc', 'title', 'ingredients']]

train_meals = meals[['fat', 'calories', 'protein', 'sodium']]
meals_desc = meals[['directions', 'desc', 'title', 'ingredients']]

# %%
train_snacks.head()
# Out:
#       fat  calories  protein  sodium
# 6306  1.0      13.0      1.0    38.0
# 4638  1.0      15.0      1.0    21.0
# 1127  1.0      15.0      1.0    26.0
# 2627  1.0      15.0      1.0    57.0
# 4792  1.0      15.0      1.0    26.0

# %%
train_meals.head()
# Out:
#        fat  calories  protein  sodium
# 8856   9.0     251.0      6.0    88.0
# 8754  11.0     251.0      5.0    90.0
# 2581  11.0     251.0      5.0   161.0
# 9630   9.0     251.0      3.0   117.0
# 4223  15.0     251.0     24.0   490.0

# %%
snacks_desc.head()
# Out:
#                                              directions  ...                                        ingredients
# 6306  [Mix first 4 ingredients in medium bowl. Cut p...  ...  [1/2 cup grated Asiago cheese*, 3/4 teaspoon d...
# 4638  [Preheat oven to 375°F with racks in upper and...  ...  [4 hickory-smoked bacon slices (1/4 pound), 3/...
# 1127  [Whisk together all ingredients in a small bow...  ...  [1 teaspoon ground cumin, 1 teaspoon ground gi...
# 2627  [Cut cucumbers crosswise into generous 1/2-inc...  ...  [4 seedless cucumbers (usually plastic-wrapped...
# 4792  [Whisk together all ingredients in a small bow...  ...  [1 teaspoon ground cumin, 1 teaspoon ground gi...
#
# [5 rows x 4 columns]

# %%
meals_desc.head()
# Out:
#                                              directions  ...                                        ingredients
# 8856  [Put one can of milk in each of 2 bowls, then ...  ...  [2 (14-ounce) cans sweetened condensed milk, 1...
# 8754  [Purée all ingredients in a blender just until...  ...  [4 cups premium vanilla ice cream, 1 cup whole...
# 2581  [Toss first 4 ingredients in medium bowl. Add ...  ...  [3/4 cup coarsely chopped gingersnaps, 1/2 cup...
# 9630  [Preheat oven to 350°F. Butter 8x8-inch metal ...  ...  [1 1/2 cups water, 1 1/2 cups chopped pitted d...
# 4223  [Preheat the oven to 325°F, Individually wrap ...  ...  [1 baguette, split in half and cut into 4 sect...
#
# [5 rows x 4 columns]

# %% [markdown]
# ### Export the Data

# %%
train_snacks.to_csv("snacks.csv", index=False)
snacks_desc.to_csv("snacks_desc.csv", index=False)
train_meals.to_csv("meals.csv", index=False)
meals_desc.to_csv("meals_desc.csv", index=False)

# %%
cal_for_snack = 52.6
train_snacks['calories'].sub(cal_for_snack).abs().idxmin()

#df['delta_n'].sub(delta_n).abs().idxmin()
# Out:
# 8392

# %%
train_snacks.loc[8392]
# Out:
# fat          4.0
# calories    53.0
# protein      3.0
# sodium      93.0
# Name: 8392, dtype: float64

# %% [markdown]
# ## Divide data

# %%
# y = json_df[['directions', 'title', 'ingredients', 'desc']]
y = json_df['title']
y.tail()
# Out:
# 15958     8551
# 15959      392
# 15960    13314
# 15961    11696
# 15962      712
# Name: title, dtype: int64

# %%
# Join columns of directions, title, ingredients and desc into one column
# with json format
#yy = pd.DataFrame(index=y.index, columns=['result'])
#for i in range(len(y)):
#    yy['result'][i] = ("{'directions':" + str(y['directions'][i]) + 
#                            ", 'title':" + str(y['title'][i]) + ", 'ingredients':" + 
#                            str(y['ingredients'][i]) + ", 'desc':" + 
#                            str(y['desc'][i]) + "}")

# %%
X = json_df[['fat', 'calories', 'protein', 'sodium']]
X.tail()
# Out:
#         fat  calories  protein  sodium
# 15958   2.0      28.0      2.0    64.0
# 15959  28.0     671.0     22.0   583.0
# 15960  38.0     563.0     31.0   652.0
# 15961  24.0     631.0     45.0   517.0
# 15962  10.0     560.0     73.0  3698.0

# %%
# Set train and test data
# set yy later for getting a json format to see all the variables the prediction has
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)
X_train.shape, X_test.shape
# Out:
# ((13568, 4), (2395, 4))

# %% [markdown]
# ## Train the Model

# %% [markdown]
# ### Create Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lnr = LinearRegression(n_jobs=1)
lnr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lnr.score(X_test, y_test)
# Out:
# -0.0009759201709598209

# %% [markdown]
# ### Instantiate Random Forest Model

# %%
import random

#from sklearn.ensemble import RandomForestClassifier

from keras.models import Sequential
from keras.layers import Dense

from sklearn.metrics import mean_squared_error

# %%
random.seed(42)
rf = RandomForestClassifier(n_estimators=10, verbose=2, max_features = 'sqrt')
rf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# building tree 1 of 10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.8s remaining:    0.0s
# building tree 2 of 10
# building tree 3 of 10
# building tree 4 of 10
# building tree 5 of 10
# building tree 6 of 10
# building tree 7 of 10
# building tree 8 of 10

# %%
# Define model
model = Sequential()
model.add(Dense(100, input_dim=4, activation= "relu"))
model.add(Dense(50, activation= "relu"))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 100)               500
# _________________________________________________________________
# dense_11 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 5,601
# Trainable params: 5,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(loss="mean_squared_error" , optimizer="adam", metrics=["accuracy"])

# %%
# Fit Model
model.fit(X_train, y_train, epochs=10000)
# Out:
# Epoch 1/10000
# 13568/13568 [==============================] - 2s 129us/step - loss: 8917824165.4811 - acc: 7.3703e-05
# Epoch 2/10000
# 13568/13568 [==============================] - 2s 122us/step - loss: 2045056065.4717 - acc: 7.3703e-05
# Epoch 3/10000
# 13568/13568 [==============================] - 2s 121us/step - loss: 1270747951.6981 - acc: 0.0000e+00
# Epoch 4/10000
# 13568/13568 [==============================] - 2s 120us/step - loss:
10000
# 13568/13568 [==============================] - 2s 124us/step - loss: 16858777.7382 - acc: 7.3703e-05
# Epoch 410/10000
# 13568/13568 [==============================] - 2s 123us/step - loss: 16751120.2476 - acc: 7.3703e-05
# Epoch 411/10000
# 13568/13568 [==============================] - 2s 125us/step - loss: 16710531.4788 - acc: 7.3703e-05
# Epoch 412/10000
# 13568/13568 [==============================] - 2s 126us/step - loss: 16685489.4151 - acc: 7.3703e-05
# Epoch 413/10000
# 13568/13568 [==============================] - 2s 120us/step - loss: 16649543.6250 - acc: 1.4741e-04
# Epoch 414/10000
# 13568/13568 [==============================] - 2s 129us/step - loss: 17567539.1981 - acc: 2.2111e-04
# Epoch 415/10000
# 13568/13568 [==============================] - 2s 127us/step - loss: 16893526.0472 - acc: 0.0000e+00
# Epoch 416/10000
# 13568/13568 [==============================] - 2s 128us/step - loss: 16681025.2689 - acc: 2.2111e-04
# Epoch 417/10000
# 13568/13568 [==============================] - 2s 125us/step - loss: 16912503.9175 - acc: 1.4741e-04
# Epoch 418/10000
# 13568/13568 [==============================] - 2s 125us/step - loss: 18374748.2288 - acc: 7.3703e-05
# Epoch 419/10000
# 13568/13568 [==============================] - 2s 129us/step - loss: 16970232.8632 - acc: 0.0000e+00
# Epoch 420/10000
# 13568/13568 [==============================] - 2s 127us/step - loss: 16704123.8137 - acc: 0.0000e+00
# Epoch 421/10000
# 13568/13568 [==============================] - 2s 125us/step - loss: 591621168.0731 - acc: 0.0000e+00
# Epoch 422/10000
# 13568/13568 [==============================] - 2s 124us/step - loss: 17396746.2087 - acc: 0.0000e+00
# Epoch 423/10000
# 13568/13568 [==============================] - 2s 127us/step - loss: 16959860.4988 - acc: 2.2111e-04
# Epoch 424/10000
# 13568/13568 [==============================] - 2s 133us/step - loss: 16858362.1651 - acc: 0.0000e+00
# Epoch 425/10000
# 13568/13568 [==============================] - 2s 133us/step - loss: 16766947.8538 - acc: 3.6851e-04
# Epoch 426/10000
#  4992/13568 [==========>...................] - ETA: 1s - loss: 16534196.0897 - acc: 0.0000e+00

# %% [markdown]
# ### Evaluate the models

# %% [markdown]
# #### Evaluate the Random Forest model

# %%
pred=rf.predict(X_test)
score = np.sqrt(mean_squared_error(y_test, pred))
score

# %% [markdown]
# #### Evaluate the NN Model

# %%
pred= model.predict(X_test)
score = np.sqrt(mean_squared_error(y_test, pred))
score

# %% [markdown]
# ### Test the model

# %% [markdown]
# ### Instantiate Logistic Regression Model

# %%
model = LogisticRegression(verbose=2)

# %% [markdown]
# ### Train the model!

# %%
in_size = 4
hidden_size = 200
out_size = len(y)
std = 1e-3

model = TwoLayerNN(in_size, hidden_size, out_size, std)

history_data = model.train(X_train, y_train, X_test, y_test, 
              learning_rate=1e-5, learning_rate_decay=0.95, 
              reg=0.0, num_iters=40, 
              batch_size=128, it_verbose = 10, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-bd581d946cb4> in <module>()
#       9               learning_rate=1e-5, learning_rate_decay=0.95,
#      10               reg=0.0, num_iters=40,
# ---> 11               batch_size=128, it_verbose = 10, verbose=True)
#
# <ipython-input-25-487579a6e79b> in train(self, X, y, X_val, y_val, learning_rate, learning_rate_decay, reg, num_iters, batch_size, it_verbose, verbose)
#      65         for it in range(num_iters):
#      66             sampling = np.random.choice(np.arange(N), batch_size, replace=False)
# ---> 67             X_batch = X[sampling]
#      68             y_batch = y[sampling]
#      69
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Int64Index([ 8941,    82,  6880, 12718,  4201,   532,  8353,   398,  5408,\n             3963,\n            ...\n            11494,  1680,  7267,   669,  9149,  9354,  8996, 13189,  6865,\n             9746],\n           dtype='int64', length=128)] are in the [columns]"
